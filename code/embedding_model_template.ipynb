# %% [markdown]
# Notebook to test different embedding models (Step 1)

# %%
# load libraries
import numpy as np
import pandas as pd

from util_funcs import load_split_data

# %%
load_split_data("../data/Sentiment_Analysis.csv")
# Out:
# (array(['Sometimes black girls just piss me off like a mother fucker!',
#         'Twitter has spoiled all the fun. Frustratingly slow!!  couldnt even bid properly!',
#         'Ha! I think I really have lost it. Time to get ready for work.',
#         ...,
#         "@JohnGunders I want Ulead back, it was awesome and it worked. But unfortunately it's only for PC",
#         '@DuaneCoffin then maybe we should ask Him for a raise.',
#         "@EricaNurney Nah... to be honest, I'm not a 'drinker' as such....  would rather have a protein shake and go for a run LOL"],
#        shape=(24000,), dtype=object),
#  array(['not in the mood crazii crazii highly upset now with everything &amp; everybody',
#         'On our way to St. Martin!!! Vacation for a week',
#         'anybody have any new song ideas?', ...,
#         'happy mothers day to all the yummy mummies on twitter',
#         "I right here...don't worry",
#         '@Carrie_King no worries. Miss you mucho'],
# ...
